# %%
# !python finding_key_bit.py --cipher-name lea --input-diff 0x80000000800000008004000080 --csv-output results.csv
# Out:
# ^C
# Running sweep on cipher lea with input difference 0x80000000800000008004000080...
# 🔎 Round 1: searching best delta-key bit (input_diff=0x80000000800000008004000080)...
# 🔍 Searching for best delta_key (Hamming weight = 1):
#
# ✅ Best delta_key bit: 95 with score = 0.82721
#     → best_bit=95, score=0.82721
# 🔎 Round 2: searching best delta-key bit (input_diff=0x80000000800000008004000080)...
# 🔍 Searching for best delta_key (Hamming weight = 1):
#
# ✅ Best delta_key bit: 95 with score = 0.79993
#     → best_bit=95, score=0.79993
# 🔎 Round 3: searching best delta-key bit (input_diff=0x80000000800000008004000080)...
# 🔍 Searching for best delta_key (Hamming weight = 1):
#
# ✅ Best delta_key bit: 95 with score = 0.73576
#     → best_bit=95, score=0.73576
# 🔎 Round 4: searching best delta-key bit (input_diff=0x80000000800000008004000080)...
# 🔍 Searching for best delta_key (Hamming weight = 1):
#
# ✅ Best delta_key bit: 64 with score = 0.60544
#     → best_bit=64, score=0.60544
# ...
