# %%
# Finding input_diff
# !python finding_input_new.py --cipher simmeck3264 --scenario single-key --rounds 8 --out "differences_results/" --verbose

# %%
# Finding key_bit
# !python finding_input_new.py --cipher simmeck3264 --scenario related-key --rounds 15 --sweep-dk --sweep-samples 10000 --difference 0x20

# %%
# Single-key
# !python visualize_dataset.py --cipher simmeck3264 --scenario single-key --rounds 7 --pairs 8 --difference 0x20 --samples 50000 --plot

# %%
# Related-key
# !python visualize_dataset.py --cipher present80 --scenario related-key --rounds 9 --pairs 32 --difference 0x0000000000000080 --key-bit 56 --samples 20000 --plot --elbow-kmax 8

# %%
# !python visualize_dataset.py --cipher speck3264 --scenario related-key --rounds 5 --pairs 2 --difference 0x400000 --key-bit 25 --samples 20000 --plot

# %%
# !python visualize_dataset.py --cipher simmeck3264 --scenario related-key --rounds 15 --pairs 32 --difference 0x40 --key-bit 57 --samples 20000 --plot

# %%
# !python visualize_dataset.py --cipher hight --scenario related-key --rounds 12 --pairs 2 --difference 0x4000000000000000 --key-bit 97 --samples 20000 --plot

# %%
# !python visualize_dataset.py --cipher lea --scenario related-key --rounds 7 --pairs 32 --difference 0x8000000080 --key-bit 94 --samples 20000 --plot

# %%
# !python /content/drive/MyDrive/NDC/Related-key-mcp-attention-Inception-based-ND/visualize_dataset.py \
    --cipher present80 \
    --rounds 8 \
    --pairs 1 \
    --difference 0xa00000000000000000000000000000000 \
    --key-bit 79 \
    --samples 50000 \
    --plot \
    --out /content/drive/MyDrive/NDC/Related-key-mcp-attention-Inception-based-ND/analysis_results \
    --add-timestamp \
    --save-sweep
